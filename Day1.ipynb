# %% [markdown]
# <a href="https://colab.research.google.com/github/namememyself/Web-Development/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/student_placement_100.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   7.5   98.0          0
# 1           1   6.9  110.0          0
# 2           2   7.6  111.0          0
# 3           3   8.5  105.0          0
# 4           4   6.8  113.0          0

# %%
df = df.iloc[:, 1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   7.5   98.0          0
# 1   6.9  110.0          0
# 2   7.6  111.0          0
# 3   8.5  105.0          0
# 4   6.8  113.0          0

# %%
plt.scatter(df['cgpa'],df['iq'],c =df['placement'])
plt.show()

# %%
X = df.iloc[:,:2]
y = df.iloc[:,2]

# %%
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: placement, dtype: int64

# %%
import sklearn.model_selection
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=2)

# %%
from sklearn.preprocessing import StandardScaler
scaler  = StandardScaler()
X_train_trf = scaler.fit_transform(X_train)
X_test_trf = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train_trf,y_train)
y_pred = clf.predict(X_test_trf)

# %%
y_test
# Out:
# 83    1
# 30    1
# 56    0
# 24    0
# 16    0
# 23    0
# 2     0
# 27    1
# 28    0
# 13    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7666666666666667

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X=X_train_trf,y=y_train.values,clf=clf)
# Out:
# <Axes: >
